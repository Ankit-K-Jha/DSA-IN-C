# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit-K-Jha/DSA-IN-C/blob/main/CNN_cat_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1:
#
# ***Importing all the Libraries.***

# %%
import tensorflow as tf
import numpy as np; import matplotlib.pyplot as mp; import sklearn; import seaborn as sns; from PIL import Image
print("All libraries imported successfull.")
# Out:
# All libraries imported successfull.

# %%
print("TensorFlow Version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow Version: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ***Loading Dataset*** through Kaggle

# %%
import json

kaggle = {
    "username": "Ankit_CUJ14",
    "key": "KGAT_f13e8b7d0281affa731690c17ddfd91e"
}

with open("kaggle.json", "w") as f:
    json.dump(kaggle, f)

# %% [markdown]
# Configuring kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.4.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.19.4)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.1.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (2026.6.17)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.16.0)

# %%
# !kaggle datasets list -s "cats and dogs"
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# ref                                                        title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# marquis03/cats-and-dogs                                    Cats and Dogs                                         10219362  2023-10-27 10:48:19.220000          17610        148                1
# mmoreaux/audio-cats-and-dogs                               Audio Cats and Dogs                                  101721956  2017-10-05 09:40:26.727000          19530        289        0.7647059
# mahmudulhaqueshawon/catcat                                 Cats and Dogs Classification                          65949527  2024-04-23 18:04:47.937000           3365        126            0.875
# samuelcortinhas/cats-and-dogs-image-classification         Cats and Dogs image classification                    67566406  2022-12-20 12:12:56.963000          45048        211            0.875
# bhavikjikadara/dog-and-cat-classification-dataset          Cats and Dogs Classification Dataset                 812748137  2023-10-07 17:44:56.873000          49411        242           0.8125
# unmoved/30k-cats-and-dogs-150x150-greyscale                30k Cats and Dogs 150x150 Greyscale                  139177677  2023-02-11 11:19:42.623000           2746         58                1
# zippyz/cats-and-dogs-breeds-classification-oxford-dataset  Cats and Dogs Breeds Classification Oxford Dataset   818292036  2019-03-12 16:17:53.420000          10528        139            0.875
# snmahsa/animal-image-dataset-cats-dogs-and-foxes           Animal Image Dataset - Cats, Dogs, and Foxes         406872199  2024-11-05 12:04:22.577000           5244         79                1
# tongpython/cat-and-dog                                     Cat and Dog                                          228487605  2018-04-26 10:56:50.843000         209054       1618             0.75
# d4rklucif3r/cat-and-dogs                                   Cat & Dogs                                           228496389  2021-06-07 11:39:13.983000          10272        134                1
# aleemaparakatta/cats-and-dogs-mini-dataset                 Cats-And-Dogs-Mini-Dataset                            22933881  2023-02-07 13:17:00.883000           8473         27             0.75
# shaunthesheep/microsoft-catsvsdogs-dataset                 Cats-vs-Dogs                                         825979578  2020-03-12 05:34:30.730000         109984        983            0.875
# ashfakyeafi/cat-dog-images-for-classification              Cat & Dog images for Classification                  571060749  2023-12-12 18:54:44.993000          12542        154                1
# tunguz/cats-and-dogs-embedded-data                         Cats and Dogs Embedded Data                         7976432264  2022-09-23 23:40:42.823000            486         19            0.625
# imsparsh/animal-breed-cats-and-dogs                        Animal Breed - Cats and Dogs                         789255162  2021-04-25 16:11:50.493000            891         25       0.88235295
# sujaykapadnis/cats-vs-dogs                                 Cats Vs Dogs                                              1926  2023-09-25 08:08:07.663000           3077         50                1
# thesherpafromalabama/cats-and-dogs-sentdex-tutorial        Cats and Dogs Sentdex Tutorial                      1653159326  2018-10-08 14:27:49.917000            597         15           0.5625
# devdgohil/the-oxfordiiit-pet-dataset                       The Oxford-IIIT Pet Dataset                          818292036  2019-06-14 20:03:38.100000           5965         50            0.875
# anshtanwar/pets-facial-expression-dataset                  🐶Pet's Facial Expression Image Dataset😸               40453464  2023-10-11 10:40:14.413000          10811        152                1
# kushleshkumar/cats-and-dogs                                Cats and Dogs                                        208817383  2020-01-05 01:39:19.367000            536         10             0.75

# %% [markdown]
# ***Downloading*** dataset

# %%
# !kaggle datasets download -d shaunthesheep/microsoft-catsvsdogs-dataset
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/shaunthesheep/microsoft-catsvsdogs-dataset
# License(s): other
# microsoft-catsvsdogs-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls /content
# Out:
# dataset  kaggle.json  microsoft-catsvsdogs-dataset.zip	sample_data

# %% [markdown]
# ***Unzipping*** dataset

# %%
import zipfile

zip_path = "/content/microsoft-catsvsdogs-dataset.zip"
extract_path = "/content/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted successfully!")
# Out:
# ✅ Dataset extracted successfully!

# %%
import os

print(os.listdir("/content/dataset"))
# Out:
# ['readme[1].txt', 'MSR-LA - 3467.docx', 'PetImages']

# %%
import os

print(os.listdir("/content/dataset/PetImages"))
# Out:
# ['Dog', 'Cat']

# %%
cat_path = "/content/dataset/PetImages/Cat"
dog_path = "/content/dataset/PetImages/Dog"

print("Cat Images :", len(os.listdir(cat_path)))
print("Dog Images :", len(os.listdir(dog_path)))
# Out:
# Cat Images : 12501
# Dog Images : 12501

# %% [markdown]
# Part 2: Dataset Loading + Preprocessing + Data Augmentation
#
# Removing Corrupted Images

# %%
import os

dataset_path = "/content/dataset/PetImages"

empty_files = []

for category in ["Cat", "Dog"]:
    folder = os.path.join(dataset_path, category)

    for filename in os.listdir(folder):
        file_path = os.path.join(folder, filename)

        if os.path.isfile(file_path):
            size = os.path.getsize(file_path)

            if size == 0:
                empty_files.append(file_path)

print("Empty files found:", len(empty_files))

for file_path in empty_files:
    print(file_path)
# Out:
# Empty files found: 2
# /content/dataset/PetImages/Cat/666.jpg
# /content/dataset/PetImages/Dog/11702.jpg

# %%
for file_path in empty_files:
    os.remove(file_path)

print("Empty files deleted:", len(empty_files))
# Out:
# Empty files deleted: 2

# %%
import os
import tensorflow as tf

dataset_path = "/content/dataset/PetImages"

bad_files = []

for category in ["Cat", "Dog"]:

    folder = os.path.join(dataset_path, category)

    for filename in os.listdir(folder):

        file_path = os.path.join(folder, filename)

        try:
            data = tf.io.read_file(file_path)

            image = tf.io.decode_image(
                data,
                channels=3,
                expand_animations=False
            )

            _ = image.numpy()

        except Exception as e:
            bad_files.append((file_path, str(e)))

print("TensorFlow-unreadable files:", len(bad_files))

for path, error in bad_files:
    print(path)
    print(error)
# Out:
# TensorFlow-unreadable files: 9
# /content/dataset/PetImages/Cat/10404.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP, WebP required. [Op:DecodeImage] name:
# /content/dataset/PetImages/Cat/Thumbs.db
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP, WebP required. [Op:DecodeImage] name:
# /content/dataset/PetImages/Cat/4351.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input size should match (header_size + row_size * abs_height) but they differ by 2 [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/9500.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/2317.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/2494.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input size should match (header_size + row_size * abs_height) but they differ by 2 [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/Thumbs.db
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Unknown image file format. One of JPEG, PNG, GIF, BMP, WebP required. [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/11233.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:
# /content/dataset/PetImages/Dog/11912.jpg
# {{function_node __wrapped__DecodeImage_device_/job:localhost/replica:0/task:0/device:CPU:0}} Number of channels inherent in the image must be 1, 3 or 4, was 2 [Op:DecodeImage] name:

# %%
for path, error in bad_files:
    os.remove(path)

print("Deleted:", len(bad_files))
# Out:
# Deleted: 9

# %% [markdown]
# Dataset dividing into training and validation phase

# %%
import tensorflow as tf

IMAGE_SIZE = (224,224)

BATCH_SIZE = 32

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(

    "/content/dataset/PetImages",

    validation_split=0.2,

    subset="training",

    seed=123,

    image_size=IMAGE_SIZE,

    batch_size=BATCH_SIZE

)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(

    "/content/dataset/PetImages",

    validation_split=0.2,

    subset="validation",

    seed=123,

    image_size=IMAGE_SIZE,

    batch_size=BATCH_SIZE

)
# Out:
# Found 24991 files belonging to 2 classes.
# Using 19993 files for training.
# Found 24991 files belonging to 2 classes.
# Using 4998 files for validation.

# %% [markdown]
# Verifying Remaining Images

# %%
print("Cat Images :", len(os.listdir(cat_path)))
print("Dog Images :", len(os.listdir(dog_path)))
# Out:
# Cat Images : 12497
# Dog Images : 12494

# %% [markdown]
# ***Class Name***

# %%
class_names = train_dataset.class_names

print(class_names)
# Out:
# ['Cat', 'Dog']

# %% [markdown]
# ***Displaying Images***

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

for images, labels in train_dataset.take(1):

    for i in range(9):

        ax = plt.subplot(3,3,i+1)

        plt.imshow(images[i].numpy().astype("uint8"))

        plt.title(class_names[labels[i]])

        plt.axis("off")

plt.show()

# %% [markdown]
# ***Normalizing Images***

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

train_dataset = train_dataset.map(

    lambda x, y: (normalization_layer(x), y)

)

validation_dataset = validation_dataset.map(

    lambda x, y: (normalization_layer(x), y)

)

# %% [markdown]
# ***Data Augmentation***

# %%
data_augmentation = tf.keras.Sequential([

    tf.keras.layers.RandomFlip("horizontal"),

    tf.keras.layers.RandomRotation(0.2),

    tf.keras.layers.RandomZoom(0.2),

    tf.keras.layers.RandomContrast(0.2)

])

# %% [markdown]
# ***Test Augmentation***

# %%
plt.figure(figsize=(8,8))

for images, labels in train_dataset.take(1):

    augmented_images = data_augmentation(images)

    for i in range(9):

        ax = plt.subplot(3,3,i+1)

        plt.imshow(augmented_images[i].numpy())

        plt.axis("off")

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0653414].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.001421].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1074327].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.019254774..1.1073517].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.027373254..1.0643018].

# %% [markdown]
# Part 3: CNN Model Building

# %%
model = tf.keras.Sequential([

    data_augmentation,

    tf.keras.layers.Conv2D(32, (3,3), activation='relu',
                           input_shape=(224,224,3)),

    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),

    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),

    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, activation='relu'),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(1, activation='sigmoid')

])

# %% [markdown]
# Part 4: ***Comiplation Phase***

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy','precision','recall','AUC']
)

# %% [markdown]
# Part 5: ***CNN Training Phase***

# %%
history = model.fit(

    train_dataset,

    validation_data=validation_dataset,

    epochs=10

)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 74ms/step - AUC: 0.6678 - accuracy: 0.6210 - loss: 0.6518 - precision: 0.6266 - recall: 0.5877 - val_AUC: 0.7201 - val_accuracy: 0.6677 - val_loss: 0.6146 - val_precision: 0.7057 - val_recall: 0.6005
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 45s 72ms/step - AUC: 0.7470 - accuracy: 0.6816 - loss: 0.5968 - precision: 0.6930 - recall: 0.6454 - val_AUC: 0.8049 - val_accuracy: 0.7261 - val_loss: 0.5456 - val_precision: 0.7606 - val_recall: 0.6776
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 77ms/step - AUC: 0.7754 - accuracy: 0.7086 - loss: 0.5712 - precision: 0.7194 - recall: 0.6783 - val_AUC: 0.8126 - val_accuracy: 0.7311 - val_loss: 0.5377 - val_precision: 0.7475 - val_recall: 0.7160
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 70ms/step - AUC: 0.7970 - accuracy: 0.7260 - loss: 0.5489 - precision: 0.7331 - recall: 0.7057 - val_AUC: 0.8485 - val_accuracy: 0.7621 - val_loss: 0.4882 - val_precision: 0.7414 - val_recall: 0.8212
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 45s 72ms/step - AUC: 0.8134 - accuracy: 0.7374 - loss: 0.5287 - precision: 0.7463 - recall: 0.7146 - val_AUC: 0.8592 - val_accuracy: 0.7779 - val_loss: 0.4705 - val_precision: 0.7696 - val_recall: 0.8075
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 48s 77ms/step - AUC: 0.8298 - accuracy: 0.7545 - loss: 0.5099 - precision: 0.7617 - recall: 0.7366 - val_AUC: 0.8763 - val_accuracy: 0.7913 - val_loss: 0.4456 - val_precision: 0.8025 - val_recall: 0.7852
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - AUC: 0.8494 - accuracy: 0.7718 - loss: 0.4826 - precision: 0.7769 - recall: 0.7588 - val_AUC: 0.8737 - val_accuracy: 0.7841 - val_loss: 0.4654 - val_precision: 0.7491 - val_recall: 0.8689
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s 72ms/step - AUC: 0.8569 - accuracy: 0.7767 - loss: 0.4732 - precision: 0.7810 - recall: 0.7653 - val_AUC: 0.8990 - val_accuracy: 0.8017 - val_loss: 0.4291 - val_precision: 0.7546 - val_recall: 0.9073
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 71ms/step - AUC: 0.8681 - accuracy: 0.7868 - loss: 0.4549 - precision: 0.7880 - recall: 0.7813 - val_AUC: 0.8939 - val_accuracy: 0.8119 - val_loss: 0.4147 - val_precision: 0.8301 - val_recall: 0.7950
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 73ms/step - AUC: 0.8762 - accuracy: 0.7957 - loss: 0.4436 - precision: 0.7988 - recall: 0.7874 - val_AUC: 0.9125 - val_accuracy: 0.8327 - val_loss: 0.3766 - val_precision: 0.8303 - val_recall: 0.8459

# %% [markdown]
# Part 6:***Model Evaluation and training***

# %%
print(history.history.keys())
# Out:
# dict_keys(['AUC', 'accuracy', 'loss', 'precision', 'recall', 'val_AUC', 'val_accuracy', 'val_loss', 'val_precision', 'val_recall'])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.plot(
    history.history['accuracy'],
    label='Training Accuracy'
)

plt.plot(
    history.history['val_accuracy'],
    label='Validation Accuracy'
)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    history.history['loss'],
    label='Training Loss'
)

plt.plot(
    history.history['val_loss'],
    label='Validation Loss'
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')

plt.legend()
plt.show()

# %%
results = model.evaluate(validation_dataset, verbose=1)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - AUC: 0.9125 - accuracy: 0.8327 - loss: 0.3766 - precision: 0.8303 - recall: 0.8459

# %%
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# loss: 0.3766
# compile_metrics: 0.8327

# %%
print(class_names)
# Out:
# ['Cat', 'Dog']

# %%
import numpy as np

y_true = []
y_pred = []

for images, labels in validation_dataset:

    predictions = model.predict(images, verbose=0)

    y_true.extend(labels.numpy())
    y_pred.extend((predictions > 0.5).astype(int).flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

print(cm)
# Out:
# [[2000  442]
#  [ 394 2162]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot()

plt.title("Cat vs Dog Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        y_true,
        y_pred,
        target_names=class_names
    )
)
# Out:
#               precision    recall  f1-score   support
#
#          Cat       0.84      0.82      0.83      2442
#          Dog       0.83      0.85      0.84      2556
#
#     accuracy                           0.83      4998
#    macro avg       0.83      0.83      0.83      4998
# weighted avg       0.83      0.83      0.83      4998

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

for images, labels in validation_dataset.take(1):

    image = images[0]
    true_label = labels[0].numpy()

    prediction = model.predict(
        tf.expand_dims(image, axis=0),
        verbose=0
    )[0][0]

    if prediction >= 0.5:
        predicted_label = 1
    else:
        predicted_label = 0

    plt.imshow(image)
    plt.axis("off")

    print("Actual:", class_names[true_label])
    print("Predicted:", class_names[predicted_label])
    print("Probability:", prediction)
# Out:
# Actual: Cat
# Predicted: Cat
# Probability: 0.24140207

# %%
probability = float(prediction)

if probability >= 0.5:
    predicted_label = "Dog"
    confidence = probability * 100
else:
    predicted_label = "Cat"
    confidence = (1 - probability) * 100

print("Actual:", class_names[true_label])
print("Predicted:", predicted_label)
print(f"Confidence: {confidence:.2f}%")
# Out:
# Actual: Cat
# Predicted: Cat
# Confidence: 75.86%

# %%
model.save("/content/cat_dog_cnn.keras")

# %%
import os

print(os.path.exists("/content/cat_dog_cnn.keras"))
# Out:
# True

# %%
model = tf.keras.models.load_model("/content/cat_dog_cnn.keras")
